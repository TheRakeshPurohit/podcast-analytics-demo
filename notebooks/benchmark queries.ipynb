# %%
from steamship import Steamship
from steamship import File, Tag

# %%
client = Steamship(profile="staging_pod")

# %% [markdown]
# #### Load guests

# %%
# %%timeit
guest_tags = Tag.query(
            client,
            tag_filter_query='filetag and kind "guest" and samefile {kind "entities"}',
        ).data.tags
assert len(guest_tags) > 0
# Out:
# 279 ms ± 7.43 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### Load topics

# %%
# %%timeit
topic_tags = Tag.query(
        client,
        tag_filter_query='blocktag and kind "entities" and samefile {filetag and kind "guest"}',
    ).data.tags
assert len(topic_tags) > 0 # TODO: is this slow because of the # entities?
# Out:
# 7.62 s ± 245 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### Fetch guests that talked about a topic

# %%
selected_topic = "Amazon"

# %%
# %%timeit
tags = Tag.query(
        client,
        tag_filter_query=f'filetag and kind "guest" and samefile {{blocktag and kind "entities" and value(\"value\") = \"{selected_topic}\"}}',
    ).data.tags
assert len(tags) > 0
# Out:
# 332 ms ± 22.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### Fetch youtube urls for a guest

# %%
selected_guest = "Jocko Willink"

# %%
# %%timeit
tags = Tag.query(
        client,
        tag_filter_query=f'filetag and kind "youtube_url" and samefile {{filetag and kind "guest" and name \"{selected_guest}\"}}',
    ).data.tags
assert len(tags) > 0
# Out:
# 208 ms ± 7.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### Fetch tags that overlap with a given topic

# %%
selected_topic = "Amazon"

# %%
# %%timeit
# First check if we can find entity tags for a selected topic
tags = Tag.query(
        client,
        tag_filter_query=f'blocktag and kind "entities" and ( value(\"value\") = \"{selected_topic}\" or name \"{selected_topic}\" )',
    ).data.tags
assert len(tags) > 0
# Out:
# 207 ms ± 11 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
overlapping_emption_tags = Tag.query(
        client,
        tag_filter_query=f'blocktag and kind "sentiments" and overlaps {{blocktag and kind "entities" and ( value(\"value\") = \"{selected_topic}\" or name \"{selected_topic}\" )}}',
    ).data.tags

len(overlapping_emption_tags) # This fails
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 overlapping_emption_tags = Tag.query(
#       2         client,
#       3         tag_filter_query=f'blocktag and kind "sentiments" and overlaps {{blocktag and kind "entities" and ( value(\"value\") = \"{selected_topic}\" or name \"{selected_topic}\" )}}',
#       4     ).data.tags
#       6 len(overlapping_emption_tags)
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/steamship/data/tags/tag.py:111, in Tag.query(client, tag_filter_query, space_id, space_handle, space)
#     102 @staticmethod
#     103 def query(
#     104     client: Client,
#    (...)
#     108     space: Any = None,
#     109 ) -> Response[TagQueryResponse]:
#     110     req = TagQueryRequest(tag_filter_query=tag_filter_query)
# --> 111     res = client.post(
#     112         "tag/query",
#     113         payload=req,
#     114         expect=TagQueryResponse,
#     115         space_id=space_id,
#     116         space_handle=space_handle,
#     117         space=space,
#     118     )
#     119     return res
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/steamship/base/client.py:430, in Client.post(self, operation, payload, file, expect, asynchronous, debug, space_id, space_handle, space, raw_response, app_call, app_owner, app_id, app_instance_id, as_background_task)
#     412 def post(
#     413     self,
#     414     operation: str,
#    (...)
#     428     as_background_task: bool = False,
#     429 ) -> Union[Any, Response[T]]:
# --> 430     return self.call(
#     431         verb="POST",
#     432         operation=operation,
#     433         payload=payload,
#     434         file=file,
#     435         expect=expect,
#     436         asynchronous=asynchronous,
#     437         debug=debug,
#     438         space_id=space_id,
#     439         space_handle=space_handle,
#     440         space=space,
#     441         raw_response=raw_response,
#     442         is_app_call=app_call,
#     443         app_owner=app_owner,
#     444         app_id=app_id,
#     445         app_instance_id=app_instance_id,
#     446         as_background_task=as_background_task,
#     447     )
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/steamship/base/client.py:354, in Client.call(self, verb, operation, payload, file, expect, asynchronous, debug, space_id, space_handle, space, raw_response, is_app_call, app_owner, app_id, app_instance_id, as_background_task)
#     352         resp = self._session.post(url, files=files, headers=headers)
#     353     else:
# --> 354         resp = self._session.post(url, json=data, headers=headers)
#     355 elif verb == Verb.GET:
#     356     resp = self._session.get(url, params=data, headers=headers)
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/requests/sessions.py:577, in Session.post(self, url, data, json, **kwargs)
#     566 def post(self, url, data=None, json=None, **kwargs):
#     567     r"""Sends a POST request. Returns :class:`Response` object.
#     568
#     569     :param url: URL for the new :class:`Request` object.
#    (...)
#     574     :rtype: requests.Response
#     575     """
# --> 577     return self.request('POST', url, data=data, json=json, **kwargs)
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Development/steamship/demos/chat-analytics-demo/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.13_3/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/homebrew/Cellar/python@3.9/3.9.13_3/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/homebrew/Cellar/python@3.9/3.9.13_3/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.9/3.9.13_3/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.9/3.9.13_3/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.13_3/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Get topic summaries for selected guest

# %%
selected_guest = "Jocko Willink"

# %%
# %%timeit
tags = Tag.query(
        client,
        tag_filter_query=f'blocktag and kind "topic_summary" and samefile {{filetag and kind "guest" and name \"{selected_guest}\"}}',
    ).data.tags
assert len(tags) > 0
# Out:
# 248 ms ± 59.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### Get chapters for selected guest

# %%
selected_guest = "Jocko Willink"

# %%
# %%timeit
tags = Tag.query(
        client,
        tag_filter_query=f'blocktag and kind "chapter" and samefile {{filetag and kind "guest" and name \"{selected_guest}\"}}',
    ).data.tags
assert len(tags) > 0
# Out:
# 205 ms ± 6.47 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
